# %%
import pandas as pd
import numpy as np
import pyodbc

# %%
conn = pyodbc.connect('DSN=WINPASS_SATEC_RO_64;')

# %%
sql1 = "select * from table_cg1"

# %%
df = pd.read_sql_query(sql=sql1, con=conn)

# %%
df.columns
# Out:
# Index(['f_NCONTRAT', 'CONTRAT', 'NC', 'REF_CGAIM', 'LCGAIM', 'AGENCE',
#        'AGENCE_A1', 'AGENCE_A2', 'AGENCE_CP', 'AGENCE_VILLE', 'CHANTIER1',
#        'CHANTIER2', 'CHANTIER3', 'CPCHANTIER', 'VILLECHANT', 'Debut', 'Fin',
#        'NATURE1', 'NATURE2', 'NATURE3', 'COUTTX', 'COUTTX1', 'COUTTX2',
#        'COUTTX3', 'COUTTX4', 'COUTTX5', 'COUTTX6', 'COUTTX7', 'COUTTX8',
#        'COUTTX9', 'GARANTIE', 'GARANTIEG', 'FRAIS', 'PRIME', 'HT', 'TTC',
#        'PRIMEG', 'TTCG', 'COM', 'ligq_commission', 'DTSITUATION', 'DOMAGIS_ON',
#        'DTRECOUVREMENT', 'MOUVEMENT', 'STATUT', 'TXCOM'],
#       dtype='object')

# %%
df[(df['CONTRAT']=='11692')&(df['NC']=='186')]
# Out:
#       f_NCONTRAT CONTRAT   NC REF_CGAIM  LCGAIM      AGENCE  \
# 14333  11692/186   11692  186    110162  110162  J REVEILLE
# 14334  11692/186   11692  186    110162  110162  J REVEILLE
# 14335  11692/186   11692  186    110162  110162  J REVEILLE
# 14336  11692/186   11692  186    110162  110162  J REVEILLE
# 14337  11692/186   11692  186    110162  110162  J REVEILLE
# 14338  11692/186   11692  186    110162  110162  J REVEILLE
# 14339  11692/186   11692  186    110162  110162  J REVEILLE
# 14340  11692/186   11692  186    110162  110162  J REVEILLE
# 14341  11692/186   11692  186    110162  110162  J REVEILLE
# 14342  11692/186   11692  186    110162  110162  J REVEILLE
# 14343  11692/186   11692  186    110162  110162  J REVEILLE
# 14344  11692/186   11692  186    110162  110162  J REVEILLE
# 14345  11692/186   11692  186    110162  110162  J REVEILLE
# 14346  11692/186   11692  186    110162  110162  J REVEILLE
# 14347  11692/186   11692  186    110162  110162  J REVEILLE
# ...

# %%
dfgroup=df[(df['CONTRAT']=='11692')&(df['NC']=='186')&(df['GARANTIE']=='G01')]

# %%
dfgroup
# Out:
#       f_NCONTRAT CONTRAT   NC REF_CGAIM  LCGAIM      AGENCE  \
# 14333  11692/186   11692  186    110162  110162  J REVEILLE
# 14334  11692/186   11692  186    110162  110162  J REVEILLE
#
#                            AGENCE_A1 AGENCE_A2 AGENCE_CP     AGENCE_VILLE  \
# 14333  Les Résidences du Port BP 162               83993  ST TROPEZ CEDEX
# 14334  Les Résidences du Port BP 162               83993  ST TROPEZ CEDEX
#
#        ... PRIMEG    TTCG     COM ligq_commission DTSITUATION DOMAGIS_ON  \
# 14333  ...  579.5  631.66  117.57          187.80  2019-10-15    DOMAGIS
# 14334  ... -579.5 -631.66    0.00         -187.81  2021-08-11    DOMAGIS
#
#                DTRECOUVREMENT MOUVEMENT        STATUT TXCOM
# 14333 2019-10-03 10:45:38.797        44  Modification  11.0
# 14334 2021-08-11 15:43:21.367         3  Modification  11.0
#
# [2 rows x 46 columns]

# %%
dfg2 = dfgroup.groupby(['CONTRAT'])['PRIMEG'].sum();dfg2
# Out:
# CONTRAT
# 11692    0.0
# Name: PRIMEG, dtype: float64

# %%
df
# Out:
#       f_NCONTRAT CONTRAT NC REF_CGAIM LCGAIM            AGENCE  \
# 0        10778/2   10778  2     27039  27039     AGENCE DU CAP
# 1        10778/2   10778  2     27039  27039     AGENCE DU CAP
# 2        10778/2   10778  2     27039  27039     AGENCE DU CAP
# 3        10778/2   10778  2     27039  27039     AGENCE DU CAP
# 4        10778/2   10778  2     27039  27039     AGENCE DU CAP
# ...          ...     ... ..       ...    ...               ...
# 59937     9191/1    9191  1      None   None  IMMOBILIERE LORI
# 59938     9191/1    9191  1      None   None  IMMOBILIERE LORI
# 59939     9191/1    9191  1      None   None  IMMOBILIERE LORI
# 59940     9191/1    9191  1      None   None  IMMOBILIERE LORI
# 59941     9191/1    9191  1      None   None  IMMOBILIERE LORI
#
#                     AGENCE_A1 AGENCE_A2 AGENCE_CP            AGENCE_VILLE  \
# 0          Avenue de la Jetée               34300              CAP D'AGDE
# ...

# %%
dfgroup
# Out:
#       f_NCONTRAT CONTRAT   NC REF_CGAIM  LCGAIM      AGENCE  \
# 14333  11692/186   11692  186    110162  110162  J REVEILLE
# 14334  11692/186   11692  186    110162  110162  J REVEILLE
#
#                            AGENCE_A1 AGENCE_A2 AGENCE_CP     AGENCE_VILLE  \
# 14333  Les Résidences du Port BP 162               83993  ST TROPEZ CEDEX
# 14334  Les Résidences du Port BP 162               83993  ST TROPEZ CEDEX
#
#        ... PRIMEG    TTCG     COM ligq_commission DTSITUATION DOMAGIS_ON  \
# 14333  ...  579.5  631.66  117.57          187.80  2019-10-15    DOMAGIS
# 14334  ... -579.5 -631.66    0.00         -187.81  2021-08-11    DOMAGIS
#
#                DTRECOUVREMENT MOUVEMENT        STATUT TXCOM
# 14333 2019-10-03 10:45:38.797        44  Modification  11.0
# 14334 2021-08-11 15:43:21.367         3  Modification  11.0
#
# [2 rows x 46 columns]

# %%
df8753_4=df[(df['CONTRAT']=='8753')&(df['NC']=='4')];df8753_4
# Out:
#       f_NCONTRAT CONTRAT NC REF_CGAIM  LCGAIM            AGENCE  \
# 59856     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59857     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59858     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59859     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59860     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59861     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59862     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59863     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59864     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59865     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59866     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59867     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59868     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# 59869     8753/4    8753  4    25 772  25 772  BILAN PATRIMOINE
# ...

# %%
df5=df8753_4.loc[df8753_4["CONTRAT"]=='8753',["CONTRAT","GARANTIE","PRIMEG"] ];df5
# Out:
#       CONTRAT GARANTIE   PRIMEG
# 59856    8753      G01  4337.21
# 59857    8753      G01 -2981.30
# 59858    8753      G02  1084.30
# 59859    8753      G02  -745.33
# 59860    8753      G03   481.91
# 59861    8753      G03  -331.26
# 59862    8753      G04   120.48
# 59863    8753      G04   -82.82
# 59864    8753      G05   298.81
# 59865    8753      G05  -205.40
# 59866    8753      G06   334.66
# 59867    8753      G06  -230.04
# 59868    8753      G07    35.86
# 59869    8753      G07   -24.65
# 59870    8753      G08     4.30
# 59871    8753      G08     1.60
# 59872    8753      GFG    48.00
# 59873    8753      SIN     0.00

# %%
df5.groupby(['CONTRAT','GARANTIE'])[['PRIMEG']].agg(np.sum)#np.sum
# Out:
#                    PRIMEG
# CONTRAT GARANTIE
# 8753    G01       1355.91
#         G02        338.97
#         G03        150.65
#         G04         37.66
#         G05         93.41
#         G06        104.62
#         G07         11.21
#         G08          5.90
#         GFG         48.00
#         SIN          0.00

# %%
df11692_186=df[(df['CONTRAT']=='11692')&(df['NC']=='186')];df11692_186
# Out:
#       f_NCONTRAT CONTRAT   NC REF_CGAIM  LCGAIM      AGENCE  \
# 14333  11692/186   11692  186    110162  110162  J REVEILLE
# 14334  11692/186   11692  186    110162  110162  J REVEILLE
# 14335  11692/186   11692  186    110162  110162  J REVEILLE
# 14336  11692/186   11692  186    110162  110162  J REVEILLE
# 14337  11692/186   11692  186    110162  110162  J REVEILLE
# 14338  11692/186   11692  186    110162  110162  J REVEILLE
# 14339  11692/186   11692  186    110162  110162  J REVEILLE
# 14340  11692/186   11692  186    110162  110162  J REVEILLE
# 14341  11692/186   11692  186    110162  110162  J REVEILLE
# 14342  11692/186   11692  186    110162  110162  J REVEILLE
# 14343  11692/186   11692  186    110162  110162  J REVEILLE
# 14344  11692/186   11692  186    110162  110162  J REVEILLE
# 14345  11692/186   11692  186    110162  110162  J REVEILLE
# 14346  11692/186   11692  186    110162  110162  J REVEILLE
# 14347  11692/186   11692  186    110162  110162  J REVEILLE
# ...

# %%
df6=df11692_186.loc[df11692_186["CONTRAT"]=='11692',["CONTRAT","GARANTIE","PRIMEG"] ];df6
# Out:
#       CONTRAT GARANTIE  PRIMEG
# 14333   11692      G01  579.50
# 14334   11692      G01 -579.50
# 14335   11692      G02  144.88
# 14336   11692      G02 -144.88
# 14337   11692      G03   64.39
# 14338   11692      G03  -64.39
# 14339   11692      G04   16.10
# 14340   11692      G04  -16.10
# 14341   11692      G05   39.93
# 14342   11692      G05  -39.93
# 14343   11692      G06   44.72
# 14344   11692      G06  -44.72
# 14345   11692      G07    4.79
# 14346   11692      G07   -4.79
# 14347   11692      G08    5.90
# 14348   11692      G08   -5.90
# 14349   11692      GFG   48.00

# %%
df6.groupby(['CONTRAT','GARANTIE'])[['PRIMEG']].agg(np.sum)#np.sum
# Out:
#                   PRIMEG
# CONTRAT GARANTIE
# 11692   G01          0.0
#         G02          0.0
#         G03          0.0
#         G04          0.0
#         G05          0.0
#         G06          0.0
#         G07          0.0
#         G08          0.0
#         GFG         48.0

# %%
#df7a=df[(df['CONTRAT']=='11692')&(df['NC']=='186')];df7a
#df7b=df7a.loc[:,["CONTRAT","NC","GARANTIE","PRIMEG"] ];df7b
df7c=df7b.groupby(['CONTRAT','NC','GARANTIE'])[['PRIMEG']].agg(np.sum);df7c#np.sum
# Out:
#                       PRIMEG
# CONTRAT NC GARANTIE
# 8753    4  G01       1355.91
#            G02        338.97
#            G03        150.65
#            G04         37.66
#            G05         93.41
#            G06        104.62
#            G07         11.21
#            G08          5.90
#            GFG         48.00
#            SIN          0.00

# %%
#df7a=df[(df['CONTRAT']=='8753')&(df['NC']=='4')];df7a
#df7b=df7a.loc[:,["CONTRAT","NC","GARANTIE","PRIMEG"] ];df7b
df7c=df7b.groupby(['CONTRAT',"NC",'GARANTIE'])[['PRIMEG']].agg(np.sum);df7c#np.sum
# Out:
#                       PRIMEG
# CONTRAT NC GARANTIE
# 8753    4  G01       1355.91
#            G02        338.97
#            G03        150.65
#            G04         37.66
#            G05         93.41
#            G06        104.62
#            G07         11.21
#            G08          5.90
#            GFG         48.00
#            SIN          0.00

# %%
df8=(df.groupby(['CONTRAT',"NC",'GARANTIE'])[['PRIMEG']].agg(np.sum)).reset_index();df8
# Out:
#       CONTRAT NC GARANTIE   PRIMEG
# 0       10778  2      G01  1355.91
# 1       10778  2      G02   338.97
# 2       10778  2      G03   150.65
# 3       10778  2      G04    37.66
# 4       10778  2      G05    93.41
# ...       ... ..      ...      ...
# 59012    9191  1      G05    72.71
# 59013    9191  1      G06    81.45
# 59014    9191  1      G07     8.73
# 59015    9191  1      G08     5.90
# 59016    9191  1      GFG    48.00
#
# [59017 rows x 4 columns]

# %%
df.shape
# Out:
# (59942, 46)

# %%
df2 =  df8.merge( df, on=['CONTRAT', 'NC','GARANTIE']);df2
# Out:
#       CONTRAT NC GARANTIE  PRIMEG_x f_NCONTRAT REF_CGAIM LCGAIM  \
# 0       10778  2      G01   1355.91    10778/2     27039  27039
# 1       10778  2      G02    338.97    10778/2     27039  27039
# 2       10778  2      G03    150.65    10778/2     27039  27039
# 3       10778  2      G04     37.66    10778/2     27039  27039
# 4       10778  2      G05     93.41    10778/2     27039  27039
# ...       ... ..      ...       ...        ...       ...    ...
# 59937    9191  1      G05     72.71     9191/1      None   None
# 59938    9191  1      G06     81.45     9191/1      None   None
# 59939    9191  1      G07      8.73     9191/1      None   None
# 59940    9191  1      G08      5.90     9191/1      None   None
# 59941    9191  1      GFG     48.00     9191/1      None   None
#
#                  AGENCE               AGENCE_A1 AGENCE_A2  ... PRIMEG_y  \
# 0         AGENCE DU CAP      Avenue de la Jetée            ...  1355.91
# ...

# %%
#df2[(df2['CONTRAT']=='8753')& (df['NC']=='4')]
#df2[(df2['CONTRAT']=='11692')& (df['NC']=='186')]
df2[(df2['CONTRAT']=='11732')& (df['NC']=='3')]
# Out:
#       CONTRAT NC GARANTIE  PRIMEG_x f_NCONTRAT REF_CGAIM LCGAIM  \
# 15078   11732  3      G01   1062.37    11732/3     24770  24770
# 15079   11732  3      G01   1062.37    11732/3     24770  24770
# 15080   11732  3      G01   1062.37    11732/3     24770  24770
# 15081   11732  3      G01   1062.37    11732/3     24770  24770
# 15082   11732  3      G02    265.59    11732/3     24770  24770
# 15083   11732  3      G03    118.04    11732/3     24770  24770
# 15084   11732  3      G04     29.51    11732/3     24770  24770
# 15085   11732  3      G05     73.19    11732/3     24770  24770
# 15086   11732  3      G06     81.97    11732/3     24770  24770
# 15087   11732  3      G07      8.78    11732/3     24770  24770
# 15088   11732  3      G08      4.30    11732/3     24770  24770
# 15089   11732  3      GFG     48.00    11732/3     24770  24770
#
#                             AGENCE               AGENCE_A1      AGENCE_A2  \
# ...

# %%
#df7a=df[(df['CONTRAT']=='11732')&(df['NC']=='3')];df7a
#df7b=df7a.loc[:,["CONTRAT","NC","GARANTIE","PRIMEG","HT","TTC"] ];df7b
#df7c=df7b.groupby(['CONTRAT',"NC",'GARANTIE'])[['PRIMEG','HT','TTC']].agg(np.sum);df7c#np.sum
# Out:
#                       PRIMEG       HT      TTC
# CONTRAT NC GARANTIE
# 11732   3  G01       1062.37  4249.48  4631.92
#            G02        265.59   265.59   289.49
#            G03        118.04   118.04   128.66
#            G04         29.51    29.51    32.17
#            G05         73.19    73.19    78.56
#            G06         81.97    81.97    89.35
#            G07          8.78     8.78     9.49
#            G08          4.30     4.30     4.30
#            GFG         48.00    48.00    48.00
